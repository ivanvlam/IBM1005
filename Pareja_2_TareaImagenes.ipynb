# %% [markdown]
# # Tarea Imagenes Biomedicas

# %% [markdown]
# ## Parte formativa
#
#
# ### Pregunta 1
#
# Considere una imagen compuesta por una cuadricula de 5x5 pixeles con los valores del 1 al 25 dispuestos como se muestra en la figura. Calcule la proyeccion a un angulo de 45°. Considere que la linea de proyeccion cruza por el centro del cuadrado.
#
# En la figura las lineas rojas muestran lineas de proyeccion para otro angulo.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Solucion

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pregunta 2
#
# Calcule la transformada de Radon del circulo unitario defindo como
#
# $$
# f(x, y) = \begin{cases}
#             0 \text{ si } x^2 + y^2 > 1 \\
#             1 \text{ si } x^2 + y^2 \le 1
#           \end{cases}
# $$

# %% [markdown]
# #### Solucion

# %% [markdown]
# Observamos que la funcion es circularmente simetrica por lo que solo necesitamos calcular para un angulo (arbitrariamente eligiremos $\theta=0$.
#
# ![alt text](https://drive.google.com/uc?export=view&id=1qKjVbU-XSN95FAeqxiXn5IyDvX3tCaOW)
#
# Como indica la figura necesitamos calcular la siguiente integral
#
# $$
# g_\theta(r) = \int^a_bf(x, y)dx
# $$
#
# La funcion es 1 dentro de interbalo de integracion, luego
#
# $$
# g_\theta(r) = \int^a_bdx
# $$
#
# Por lo tanto nos basta con conocer los valores de a y b. Dado que es un circulo unitario tenemos,
#
# $$
# g_\theta(r) = \int^{\sqrt{1 - r^2}}_{-\sqrt{1 - r^2}}dx
# $$
#
# Luego
#
# $$
# g_\theta(r) = \begin{cases}
#               2\sqrt{1-r^2} \text{ si } |r| \le 1 \\
#               0 \text{ e.o.c}
#           \end{cases}
# $$

# %% [markdown]
# ###  Pregunta 3
#
# Calcule usando [sikit-image](https://scikit-image.org/docs/dev/auto_examples/transform/plot_radon_transform.html) la transformada de la pregunta anterior. Comparela con la calculada analiticamente.

# %% [markdown]
# #### Solucion

# %%
import numpy as np
import matplotlib.pyplot as plt

# creamos una grilla con valores de x e y
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)

xx, yy = np.meshgrid(x, y)

# %%
def sphere(x, y, r):
    return 1*(x**2 + y**2 < 1)

s = sphere(xx, yy, 1)

plt.imshow(s, cmap='gray')

# %%
from skimage.transform import radon, rescale
theta = np.linspace(0., 180., 100, endpoint=False)
sinogram = radon(s, theta=theta, preserve_range=True)

plt.imshow(sinogram, cmap='gray')
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/transform/radon_transform.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   coords = np.array(np.ogrid[:image.shape[0], :image.shape[1]])

# %%
# comparemos con la encontrada analiticamente
r = np.linspace(-2, 2, 100)
g = np.zeros_like(r)
g = np.where(np.abs(r) < 1, 2*(np.sqrt(1 - r**2)), 0 )

plt.title("Transformada de Radon de la imagen")
plt.plot(sinogram[:, 0])
plt.show()
plt.title("Transformada de Radon analitica")
plt.plot(r, g)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in sqrt
#   after removing the cwd from sys.path.

# %% [markdown]
# ---

# %% [markdown]
# ## Parte evaluada
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# creamos una grilla con valores de x e y
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)

xx, yy = np.meshgrid(x, y)

# %%
def circulo_origen(x, y, r):
    return 1*(x**2 + y**2 < 1)

s = circulo_origen(xx, yy, 1)

plt.imshow(s, cmap='gray')

# %%
from skimage.transform import radon, rescale
theta = np.linspace(0., 180., 100, endpoint=False)
sinogram = radon(s, theta=theta, preserve_range=True)

plt.imshow(sinogram, cmap='gray')
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/transform/radon_transform.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   coords = np.array(np.ogrid[:image.shape[0], :image.shape[1]])

# %%
def circulo_desplazado(x, y, r):
    return 1*((x - 1/2)**2 + y**2 < 1/4)

s = circulo_desplazado(xx, yy, 1/2)

plt.imshow(s, cmap='gray')

# %%
from skimage.transform import radon, rescale
theta = np.linspace(0., 180., 200, endpoint=False)
sinogram = radon(s, theta=theta, preserve_range=True)

plt.imshow(sinogram, cmap='gray')
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/transform/radon_transform.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   coords = np.array(np.ogrid[:image.shape[0], :image.shape[1]])

# %%
def cuadrado(x, y, r):
    return 1*(abs(x) < 1/2) & 1*(abs(y) < 1/2)

s = cuadrado(xx, yy, 1)

plt.imshow(s, cmap='gray')

# %%
from skimage.transform import radon, rescale
theta = np.linspace(0., 180., 100, endpoint=False)
sinogram = radon(s, theta=theta, preserve_range=True)

plt.imshow(sinogram, cmap='gray')
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/transform/radon_transform.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   coords = np.array(np.ogrid[:image.shape[0], :image.shape[1]])

# %%
def rombos(x, y, r):
    return 1*(abs(x + y) + 1/8 > 1/2) & 1*(abs(x - y) + 1/8 > 1/2) & 1*(abs(x - y) + 1/8 < 3/2) & 1*(abs(x + y) + 1/8 < 3/2) & 1*(abs(x**10 + y) > 1/4) & 1*(abs(x) < 1/2)

s = rombos(xx, yy, 1)

plt.imshow(s, cmap='gray')

# %%
from skimage.transform import radon, rescale
theta = np.linspace(0., 180., 200, endpoint=False)
sinogram = radon(s, theta=theta, preserve_range=True)

plt.imshow(sinogram, cmap='gray')
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/transform/radon_transform.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   coords = np.array(np.ogrid[:image.shape[0], :image.shape[1]])

# %%
def rombos_desplazados(x, y, r):
    return 1*(x + y > 1/2) & 1*(x - y < -1/2) & 1*(x + y < 3/2)  & 1*(x - y > -3/2) | 1*(x + y < -1) & 1*(x - y > -1) & 1*(x + y > -2) & 1*(x - y < 0)

s = rombos_desplazados(xx, yy, 1)

plt.imshow(s, cmap='gray')

# %%
from skimage.transform import radon, rescale
theta = np.linspace(0., 180., 200, endpoint=False)
sinogram = radon(s, theta=theta, preserve_range=True)

plt.imshow(sinogram, cmap='gray')
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/transform/radon_transform.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   coords = np.array(np.ogrid[:image.shape[0], :image.shape[1]])

# %% [markdown]
# A partir de lo anterior, se puede observar que:
# - Los dos rombos alineados corresponden al senograma f.
# - El cuadrado centrado en el origen corresponde al senograma e.
# - El círculo desplazado corresponde al senograma d.
# - El círculo centrado en el origen corresponde al senograma b.
# - El rombo alineado en el centro junto al rombo desplazado a la izquierda corresponden al senograma a.
#
# En consecuencia, y debido a la complejidad del senograma c, este último corresponde a la imagen del hombre con la cámara fotográfica.

# %% [markdown]
# ### Pregunta 2
#
# Considere el objeto de la siguiente figura, el
# cual corresponde a un triangulo equilátero centrado en el origen, de lado a y tiene un lado paralelo al eje x. Considere que el objeto tiene un coeficiente lineal de atenuación u = 1, y a =6.
#
# Calcule una fórmula para la proyección g(r,60°) y dibújela

# %% [markdown]
# ![trian.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

x = [-3,3,0,-3]
y = [-1.299,-1.299,1.299,-1.299]

plt.xlim(-4,4)
plt.ylim(-1.5,1.5)
plt.grid()
plt.plot(x, y)

# %% [markdown]
# ![WhatsApp Image 2021-06-18 at 18.48.05.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# $\text{Finalmente, }g_{60^°}(r)=
# \left\{
# \begin{gather*}
# \sqrt{3}\cdot(3+r) & \quad r \in [-3,0] \\
# \sqrt{3}\cdot(3-r) & \quad r \in [0,3] \\
# 0 & \quad |r|\gt 3
# \end{gather*}
# \right.$

# %%
import matplotlib.pyplot as plt
import numpy as np

h = 3 * np.sqrt(2)

x = [i for i in range(11)]
y = [0 for i in range(3)] + [h/3, 2*h/3, h, 2*h/3, h/3] + [0 for i in range(3)] 

plt.title("Proyección del triángulo (valores referenciales)")
plt.xlim(0,10)
plt.ylim(0,5)
plt.plot(x, y)

# %% [markdown]
# ### Pregunta 3

# %% [markdown]
# Calcule anlaliticamente la transofrmada de radon de la siguiente figura.
#
# Ayuda: Considere la transformada de Radón del círculo unitario de la parte formativa y utilice el hecho que la transformada de Radón es **lineal**.
#
# $F: V \rightarrow W$ es una transformada lineal si cumple que
#
# 1. $F(u+v)=F(u)+F(v) \quad \forall u, v \in V$
# 2. $F(k . v)=k . F(v) \quad \forall v \in V, \quad \forall k \in \mathbb{R}$

# %% [markdown]
# ![Figura 1](https://drive.google.com/uc?export=view&id=1xzFQzyLumtvf1v6ZQkFhNNBGkhK_Pv8N)

# %%
import numpy as np
import matplotlib.pyplot as plt

# creamos una grilla con valores de x e y
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)

xx, yy = np.meshgrid(x, y)

# %%
def disco(x, y, r):
    return 1*(x**2 + y**2 < 1) & 1*(x**2 + y**2 > 1/4)

s = disco(xx, yy, 1)

plt.imshow(s, cmap='gray')

# %%
from skimage.transform import radon, rescale
theta = np.linspace(0., 180., 100, endpoint=False)
sinogram = radon(s, theta=theta, preserve_range=True)

plt.imshow(sinogram, cmap='gray')
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/transform/radon_transform.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   coords = np.array(np.ogrid[:image.shape[0], :image.shape[1]])

# %%
r = np.linspace(-2, 2, 100)

plt.title("Transformada de Radon del disco")
plt.plot(sinogram[:, 0])
plt.show()

# %%
def circulo_grande(x, y, r):
    return 1*(x**2 + y**2 < 1)

s = circulo_grande(xx, yy, 1)

plt.imshow(s, cmap='gray')

# %%
from skimage.transform import radon, rescale
theta = np.linspace(0., 180., 100, endpoint=False)
sinogram_grande = radon(s, theta=theta, preserve_range=True)

plt.imshow(sinogram_grande, cmap='gray')
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/transform/radon_transform.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   coords = np.array(np.ogrid[:image.shape[0], :image.shape[1]])

# %%
def circulo_chico(x, y, r):
    return 1*(x**2 + y**2 < 1/4)

s = circulo_chico(xx, yy, 1/2)

plt.imshow(s, cmap='gray')

# %%
from skimage.transform import radon, rescale
theta = np.linspace(0., 180., 100, endpoint=False)
sinogram_chico = radon(s, theta=theta, preserve_range=True)

plt.imshow(sinogram_chico, cmap='gray')
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/transform/radon_transform.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   coords = np.array(np.ogrid[:image.shape[0], :image.shape[1]])

# %%
r = np.linspace(-2, 2, 100)
g = np.zeros_like(r)
g1 = np.where(np.abs(r) < 1, 2*(np.sqrt(1 - r**2)), 0 )
g2 = np.where(np.abs(r) < 1/2, 2*(np.sqrt(1/4 - r**2)), 0 )

fig, ax = plt.subplots(2, 2, figsize = (12, 12))

ax[0][0].set_title("Transformada de Radon del circulo grande")
ax[0][0].plot(sinogram_grande[:, 0])

ax[0][1].set_title("Transformada de Radon del circulo chico")
ax[0][1].plot(sinogram_chico[:, 0])

ax[1][0].set_title("Transformada de Radon analitica círculo grande")
ax[1][0].plot(r, g1)

ax[1][1].set_title("Transformada de Radon analitica círculo chico")
ax[1][1].plot(r, g2)

fig.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in sqrt
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in sqrt
#   after removing the cwd from sys.path.

# %%
r = np.linspace(-2, 2, 100)
g = np.zeros_like(r)

fig, ax = plt.subplots(2, 1, figsize = (8, 12))

ax[0].set_title("Transformada de Radon resta de círculos")
ax[0].plot(sinogram_grande[:, 0] - sinogram_chico[:, 0])

ax[1].set_title("Transformada de Radon analitica")
ax[1].plot(r, g1 - g2)

fig.show()

# %% [markdown]
# A partir de los gráficos, se puede apreciar que mediante la representación gráfica del disco y la de la resta de círculos concentricos se generó la misma transformada de Radón, lo que es de esperarse, debido a la linealidad de esta. Además, mediante el segundo método se pudo calcular la transformada de Radón analítica, que corresponde a un gráfico más suave y con mucho menos ruido.
